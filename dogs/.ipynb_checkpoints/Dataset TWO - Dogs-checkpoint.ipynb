# %% [markdown]
# # Homework 6, Part Two: A dataset about dogs.
#
# Data from [a FOIL request to New York City](https://www.muckrock.com/foi/new-york-city-17/pet-licensing-data-for-new-york-city-23826/)

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ## Read in the file `NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx` and look at the first five rows

# %%
df = pd.read_excel("NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx", nrows=30000, na_values=["Unknown", "UNKNOWN"])
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# 1                NaN   2013-04-01             No               No        Yes
# 2                NaN   2014-09-01            Yes              NaN         No
# 3                NaN   2008-04-01            Yes               No        Yes
# 4                NaN   2014-01-01             No              NaN         No
#
#          Application Date License Issued Date License Expired Date
# 0 2012-09-19 16:01:19.647          2015-09-19           2016-09-19
# 1 2013-09-20 11:41:36.647          2014-09-20           2018-09-20
# 2 2014-09-12 13:13:36.713          2014-09-12           2019-09-12
# 3 2014-09-12 15:26:51.417          2014-09-12           2017-10-20
# 4 2014-09-12 15:43:17.707          2014-09-12           2019-09-12

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?
#
# If there are more than 30,000 rows in your dataset, go back and only read in the first 30,000.

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Owner Zip Code          30000 non-null  int64
#  1   Animal Name             29540 non-null  object
#  2   Animal Gender           30000 non-null  object
#  3   Primary Breed           25223 non-null  object
#  4   Secondary Breed         3974 non-null   object
#  5   Animal Dominant Color   29885 non-null  object
#  6   Animal Secondary Color  20946 non-null  object
#  7   Animal Third Color      6629 non-null   object
#  8   Animal Birth            30000 non-null  datetime64[ns]
#  9   Spayed or Neut          30000 non-null  object
#  10  Guard or Trained        19826 non-null  object
#  11  Vaccinated              30000 non-null  object
#  12  Application Date        30000 non-null  datetime64[ns]
#  13  License Issued Date     30000 non-null  datetime64[ns]
#  14  License Expired Date    30000 non-null  datetime64[ns]
# dtypes: datetime64[ns](4), int64(1), object(10)
# memory usage: 3.4+ MB

# %% [markdown]
# ## Describe the dataset in words. What is each row? List two column titles along with what each of those columns means.
#
# For example: “Each row is an animal in the zoo. `is_reptile` is whether the animal is a reptile or not”

# %% [markdown]
# Each row is a dog in New York City. `Primary Breed` gives the dog's breed and `License Issued Date` gives the date the pet became registered.

# %% [markdown]
# # Your thoughts
#
# Think of four questions you could ask this dataset. **Don't ask them**, just write them down in the cell below. Feel free to use either Markdown or Python comments.

# %% [markdown]
# 1. What is the most popular breed?
# 2. What is the average dog age?
# 3. What are the 3 most common dog colors?
# 4. What percentage of dogs are spayed and neutered?

# %% [markdown]
# # Looking at some dogs

# %% [markdown]
# ## What are the most popular (primary) breeds of dogs? Graph the top 10.

# %%
df_breeds = df['Primary Breed'].value_counts().head(10)
df_breeds
# Out:
# Yorkshire Terrier                       1882
# Shih Tzu                                1760
# Chihuahua                               1535
# Maltese                                 1133
# Labrador Retriever                      1074
# American Pit Bull Terrier/Pit Bull       780
# Labrador Retriever Crossbreed            738
# American Pit Bull Mix / Pit Bull Mix     722
# Jack Russell Terrier                     553
# Beagle                                   546
# Name: Primary Breed, dtype: int64

# %%
df_breeds.sort_values(ascending=True).plot(kind='barh', x='Primary Breed')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## "Unknown" is a terrible breed! Graph the top 10 breeds that are NOT Unknown

# %%
# Added 'na_values=["Unknown"]' to read_csv above
df_breeds.sort_values(ascending=True).plot(kind='barh', x='Primary Breed')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## What are the most popular dog names?

# %%
df['Animal Name'].value_counts().head(10)
# Out:
# Max        202
# Bella      193
# Charlie    172
# Lola       146
# Rocky      140
# Lucy       128
# Coco       114
# Buddy      113
# Lucky      106
# Daisy       90
# Name: Animal Name, dtype: int64

# %% [markdown]
# ## Do any dogs have your name? How many dogs are named "Max," and how many are named "Maxwell"?

# %%
df[df['Animal Name'] == 'Brianna'].shape
# Out:
# (2, 15)

# %%
df[df['Animal Name'] == 'Max'].shape
# Out:
# (202, 15)

# %%
df[df['Animal Name'] == 'Maxwell'].shape
# Out:
# (11, 15)

# %% [markdown]
# ## What percentage of dogs are guard dogs?
#
# Check out the documentation for [value counts](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html).

# %%
df['Guard or Trained'].value_counts(normalize=True)*100
# Out:
# No     99.914254
# Yes     0.085746
# Name: Guard or Trained, dtype: float64

# %% [markdown]
# ## What are the actual numbers?

# %%
df['Guard or Trained'].value_counts()
# Out:
# No     19809
# Yes       17
# Name: Guard or Trained, dtype: int64

# %% [markdown]
# ## Wait... if you add that up, is it the same as your number of rows? Where are the other dogs???? How can we find them??????
#
# Use your `.head()` to think about it, then you'll do some magic with `.value_counts()`

# %%
df['Guard or Trained'].value_counts(dropna=False)
# Out:
# No     19809
# NaN    10174
# Yes       17
# Name: Guard or Trained, dtype: int64

# %% [markdown]
# ## Fill in all of those empty "Guard or Trained" columns with "No"
#
# Then check your result with another `.value_counts()`

# %%
df['Guard or Trained'] = df['Guard or Trained'].fillna("No")

# %%
df["Guard or Trained"].value_counts()
# Out:
# No     29983
# Yes       17
# Name: Guard or Trained, dtype: int64

# %% [markdown]
# ## What are the top dog breeds for guard dogs?

# %%
df_guard = df[df["Guard or Trained"] == "Yes"]

# %%
df_guard["Primary Breed"].value_counts()
# Out:
# German Shepherd Dog           3
# Labrador Retriever            1
# German Shepherd Crossbreed    1
# Rottweiler                    1
# Poodle, Standard              1
# Doberman Pinscher             1
# Schnauzer, Miniature          1
# Golden Retriever              1
# Yorkshire Terrier             1
# Shih Tzu                      1
# Name: Primary Breed, dtype: int64

# %% [markdown]
# ## Create a new column called "year" that is the dog's year of birth
#
# The `Animal Birth` column is a datetime, so you can get the year out of it with the code `df['Animal Birth'].apply(lambda birth: birth.year)`.

# %%
df["year"] = df["Animal Birth"].apply(lambda birth: birth.year)
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# 1                NaN   2013-04-01             No               No        Yes
# 2                NaN   2014-09-01            Yes               No         No
# 3                NaN   2008-04-01            Yes               No        Yes
# 4                NaN   2014-01-01             No               No         No
#
#          Application Date License Issued Date License Expired Date  year
# 0 2012-09-19 16:01:19.647          2015-09-19           2016-09-19  2007
# 1 2013-09-20 11:41:36.647          2014-09-20           2018-09-20  2013
# 2 2014-09-12 13:13:36.713          2014-09-12           2019-09-12  2014
# 3 2014-09-12 15:26:51.417          2014-09-12           2017-10-20  2008
# 4 2014-09-12 15:43:17.707          2014-09-12           2019-09-12  2014

# %% [markdown]
# ## Calculate a new column called “age” that shows approximately how old the dog is. How old are dogs on average?

# %%
df["age"] = pd.datetime.now().year - df["year"]
# Out:
# <ipython-input-54-bf18834c07fa>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   df["age"] = pd.datetime.now().year - df["year"]

# %%
df.age.mean().round(2)
# Out:
# 11.71

# %% [markdown]
# # Joining data together

# %% [markdown]
# ## Which neighborhood does each dog live in?
#
# You also have a (terrible) list of NYC neighborhoods in `zipcodes-neighborhoods.csv`. Join these two datasets together, so we know what neighborhood each dog lives in. **Be sure to not read it in as `df`, or else you'll overwrite your dogs dataframe.**

# %%
df_neighborhoods = pd.read_csv("zipcodes-neighborhoods.csv")
df_neighborhoods
# Out:
#                       neighborhood    zip        borough
# 0                    Central Bronx  10453          Bronx
# 1                    Central Bronx  10457          Bronx
# 2                    Central Bronx  10460          Bronx
# 3           Bronx Park and Fordham  10458          Bronx
# 4           Bronx Park and Fordham  10467          Bronx
# 5           Bronx Park and Fordham  10468          Bronx
# 6       High Bridge and Morrisania  10451          Bronx
# 7       High Bridge and Morrisania  10452          Bronx
# 8       High Bridge and Morrisania  10456          Bronx
# 9       Hunts Point and Mott Haven  10454          Bronx
# 10      Hunts Point and Mott Haven  10455          Bronx
# 11      Hunts Point and Mott Haven  10459          Bronx
# 12      Hunts Point and Mott Haven  10474          Bronx
# 13       Kingsbridge and Riverdale  10463          Bronx
# 14       Kingsbridge and Riverdale  10471          Bronx
# 15                 Northeast Bronx  10466          Bronx
# 16                 Northeast Bronx  10469          Bronx
# 17                 Northeast Bronx  10470          Bronx
# 18                 Northeast Bronx  10475          Bronx
# 19                 Southeast Bronx  10461          Bronx
# 20                 Southeast Bronx  10462          Bronx
# 21                 Southeast Bronx  10464          Bronx
# 22                 Southeast Bronx  10465          Bronx
# 23                 Southeast Bronx  10472          Bronx
# 24                 Southeast Bronx  10473          Bronx
# 25                Central Brooklyn  11212       Brooklyn
# 26                Central Brooklyn  11213       Brooklyn
# 27                Central Brooklyn  11216       Brooklyn
# 28                Central Brooklyn  11233       Brooklyn
# 29                Central Brooklyn  11238       Brooklyn
# 30              Southwest Brooklyn  11209       Brooklyn
# 31              Southwest Brooklyn  11214       Brooklyn
# 32              Southwest Brooklyn  11228       Brooklyn
# 33                    Borough Park  11204       Brooklyn
# 34                    Borough Park  11218       Brooklyn
# 35                    Borough Park  11219       Brooklyn
# 36                    Borough Park  11230       Brooklyn
# 37          Canarsie and Flatlands  11234       Brooklyn
# 38          Canarsie and Flatlands  11236       Brooklyn
# 39          Canarsie and Flatlands  11239       Brooklyn
# 40               Southern Brooklyn  11223       Brooklyn
# 41               Southern Brooklyn  11224       Brooklyn
# 42               Southern Brooklyn  11229       Brooklyn
# 43               Southern Brooklyn  11235       Brooklyn
# 44              Northwest Brooklyn  11201       Brooklyn
# 45              Northwest Brooklyn  11205       Brooklyn
# 46              Northwest Brooklyn  11215       Brooklyn
# 47              Northwest Brooklyn  11217       Brooklyn
# 48              Northwest Brooklyn  11231       Brooklyn
# 49                        Flatbush  11203       Brooklyn
# 50                        Flatbush  11210       Brooklyn
# 51                        Flatbush  11225       Brooklyn
# 52                        Flatbush  11226       Brooklyn
# 53      East New York and New Lots  11207       Brooklyn
# 54      East New York and New Lots  11208       Brooklyn
# 55                      Greenpoint  11211       Brooklyn
# 56                      Greenpoint  11222       Brooklyn
# 57                     Sunset Park  11220       Brooklyn
# 58                     Sunset Park  11232       Brooklyn
# 59       Bushwick and Williamsburg  11206       Brooklyn
# 60       Bushwick and Williamsburg  11221       Brooklyn
# 61       Bushwick and Williamsburg  11237       Brooklyn
# 62                  Central Harlem  10026      Manhattan
# 63                  Central Harlem  10027      Manhattan
# 64                  Central Harlem  10030      Manhattan
# 65                  Central Harlem  10037      Manhattan
# 66                  Central Harlem  10039      Manhattan
# 67             Chelsea and Clinton  10001      Manhattan
# 68             Chelsea and Clinton  10011      Manhattan
# 69             Chelsea and Clinton  10018      Manhattan
# 70             Chelsea and Clinton  10019      Manhattan
# 71             Chelsea and Clinton  10020      Manhattan
# 72             Chelsea and Clinton  10036      Manhattan
# 73                     East Harlem  10029      Manhattan
# 74                     East Harlem  10035      Manhattan
# 75   Gramercy Park and Murray Hill  10010      Manhattan
# 76   Gramercy Park and Murray Hill  10016      Manhattan
# 77   Gramercy Park and Murray Hill  10017      Manhattan
# 78   Gramercy Park and Murray Hill  10022      Manhattan
# 79      Greenwich Village and Soho  10012      Manhattan
# 80      Greenwich Village and Soho  10013      Manhattan
# 81      Greenwich Village and Soho  10014      Manhattan
# 82                 Lower Manhattan  10004      Manhattan
# 83                 Lower Manhattan  10005      Manhattan
# 84                 Lower Manhattan  10006      Manhattan
# 85                 Lower Manhattan  10007      Manhattan
# 86                 Lower Manhattan  10038      Manhattan
# 87                 Lower Manhattan  10280      Manhattan
# 88                 Lower East Side  10002      Manhattan
# 89                 Lower East Side  10003      Manhattan
# 90                 Lower East Side  10009      Manhattan
# 91                 Upper East Side  10021      Manhattan
# 92                 Upper East Side  10028      Manhattan
# 93                 Upper East Side  10044      Manhattan
# 94                 Upper East Side  10065      Manhattan
# 95                 Upper East Side  10075      Manhattan
# 96                 Upper East Side  10128      Manhattan
# 97                 Upper West Side  10023      Manhattan
# 98                 Upper West Side  10024      Manhattan
# 99                 Upper West Side  10025      Manhattan
# 100  Inwood and Washington Heights  10031      Manhattan
# 101  Inwood and Washington Heights  10032      Manhattan
# 102  Inwood and Washington Heights  10033      Manhattan
# 103  Inwood and Washington Heights  10034      Manhattan
# 104  Inwood and Washington Heights  10040      Manhattan
# 105               Northeast Queens  11361         Queens
# 106               Northeast Queens  11362         Queens
# 107               Northeast Queens  11363         Queens
# 108               Northeast Queens  11364         Queens
# 109                   North Queens  11354         Queens
# 110                   North Queens  11355         Queens
# 111                   North Queens  11356         Queens
# 112                   North Queens  11357         Queens
# 113                   North Queens  11358         Queens
# 114                   North Queens  11359         Queens
# 115                   North Queens  11360         Queens
# 116                 Central Queens  11365         Queens
# 117                 Central Queens  11366         Queens
# 118                 Central Queens  11367         Queens
# 119                        Jamaica  11412         Queens
# 120                        Jamaica  11423         Queens
# 121                        Jamaica  11432         Queens
# 122                        Jamaica  11433         Queens
# 123                        Jamaica  11434         Queens
# 124                        Jamaica  11435         Queens
# 125                        Jamaica  11436         Queens
# 126               Northwest Queens  11101         Queens
# 127               Northwest Queens  11102         Queens
# 128               Northwest Queens  11103         Queens
# 129               Northwest Queens  11104         Queens
# 130               Northwest Queens  11105         Queens
# 131               Northwest Queens  11106         Queens
# 132            West Central Queens  11374         Queens
# 133            West Central Queens  11375         Queens
# 134            West Central Queens  11379         Queens
# 135            West Central Queens  11385         Queens
# 136                      Rockaways  11691         Queens
# 137                      Rockaways  11692         Queens
# 138                      Rockaways  11693         Queens
# 139                      Rockaways  11694         Queens
# 140                      Rockaways  11695         Queens
# 141                      Rockaways  11697         Queens
# 142               Southeast Queens  11004         Queens
# 143               Southeast Queens  11005         Queens
# 144               Southeast Queens  11411         Queens
# 145               Southeast Queens  11413         Queens
# 146               Southeast Queens  11422         Queens
# 147               Southeast Queens  11426         Queens
# 148               Southeast Queens  11427         Queens
# 149               Southeast Queens  11428         Queens
# 150               Southeast Queens  11429         Queens
# 151               Southwest Queens  11414         Queens
# 152               Southwest Queens  11415         Queens
# 153               Southwest Queens  11416         Queens
# 154               Southwest Queens  11417         Queens
# 155               Southwest Queens  11418         Queens
# 156               Southwest Queens  11419         Queens
# 157               Southwest Queens  11420         Queens
# 158               Southwest Queens  11421         Queens
# 159                    West Queens  11368         Queens
# 160                    West Queens  11369         Queens
# 161                    West Queens  11370         Queens
# 162                    West Queens  11372         Queens
# 163                    West Queens  11373         Queens
# 164                    West Queens  11377         Queens
# 165                    West Queens  11378         Queens
# 166                  Port Richmond  10302  Staten Island
# 167                  Port Richmond  10303  Staten Island
# 168                  Port Richmond  10310  Staten Island
# 169                    South Shore  10306  Staten Island
# 170                    South Shore  10307  Staten Island
# 171                    South Shore  10308  Staten Island
# 172                    South Shore  10309  Staten Island
# 173                    South Shore  10312  Staten Island
# 174       Stapleton and St. George  10301  Staten Island
# 175       Stapleton and St. George  10304  Staten Island
# 176       Stapleton and St. George  10305  Staten Island
# 177                     Mid-Island  10314  Staten Island

# %%
df = df.merge(df_neighborhoods, left_on='Owner Zip Code', right_on='zip')

# %% [markdown]
# ## What is the most popular dog name in all parts of the Bronx? How about Brooklyn? The Upper East Side?

# %%
df[df['borough'] == "Bronx"]["Animal Name"].value_counts().head(1)
# Out:
# Bella    22
# Name: Animal Name, dtype: int64

# %%
df[df['borough'] == "Brooklyn"]["Animal Name"].value_counts().head(1)
# Out:
# Max    46
# Name: Animal Name, dtype: int64

# %%
df[df['neighborhood'] == "Upper East Side"]["Animal Name"].value_counts().head(1)
# Out:
# Charlie    19
# Name: Animal Name, dtype: int64

# %% [markdown]
# ## What is the most common dog breed in each of the neighborhoods of NYC?

# %%
df_new = pd.DataFrame(df.groupby('neighborhood')['Primary Breed'].value_counts().groupby(level=0).nlargest(1))
df_new
# Out:
#                                                                                                   Primary Breed
# neighborhood                  neighborhood                  Primary Breed
# Borough Park                  Borough Park                  Yorkshire Terrier                                49
# Bronx Park and Fordham        Bronx Park and Fordham        Yorkshire Terrier                                39
# Bushwick and Williamsburg     Bushwick and Williamsburg     Yorkshire Terrier                                47
# Canarsie and Flatlands        Canarsie and Flatlands        Shih Tzu                                         56
# Central Bronx                 Central Bronx                 Yorkshire Terrier                                29
# Central Brooklyn              Central Brooklyn              Shih Tzu                                         52
# Central Harlem                Central Harlem                Chihuahua                                        48
# Central Queens                Central Queens                Yorkshire Terrier                                34
# Chelsea and Clinton           Chelsea and Clinton           Chihuahua                                        80
# East Harlem                   East Harlem                   Yorkshire Terrier                                44
# East New York and New Lots    East New York and New Lots    Yorkshire Terrier                                25
# Flatbush                      Flatbush                      Shih Tzu                                         38
# Gramercy Park and Murray Hill Gramercy Park and Murray Hill Yorkshire Terrier                                52
# Greenpoint                    Greenpoint                    Chihuahua                                        40
# Greenwich Village and Soho    Greenwich Village and Soho    Labrador Retriever                               35
# High Bridge and Morrisania    High Bridge and Morrisania    Shih Tzu                                         33
# Hunts Point and Mott Haven    Hunts Point and Mott Haven    Chihuahua                                        37
# Inwood and Washington Heights Inwood and Washington Heights Chihuahua                                        48
# Jamaica                       Jamaica                       Yorkshire Terrier                                41
# Kingsbridge and Riverdale     Kingsbridge and Riverdale     Shih Tzu                                         26
# Lower East Side               Lower East Side               Chihuahua                                        77
# Lower Manhattan               Lower Manhattan               Shih Tzu                                         24
# Mid-Island                    Mid-Island                    Yorkshire Terrier                                36
# North Queens                  North Queens                  Maltese                                          54
# Northeast Bronx               Northeast Bronx               Yorkshire Terrier                                35
# Northeast Queens              Northeast Queens              Maltese                                          29
# Northwest Brooklyn            Northwest Brooklyn            Labrador Retriever                               72
# Northwest Queens              Northwest Queens              Chihuahua                                        62
# Port Richmond                 Port Richmond                 American Pit Bull Mix / Pit Bull Mix             22
# Rockaways                     Rockaways                     Shih Tzu                                         24
# South Shore                   South Shore                   Shih Tzu                                         90
# Southeast Bronx               Southeast Bronx               Shih Tzu                                         83
# Southeast Queens              Southeast Queens              Yorkshire Terrier                                35
# Southern Brooklyn             Southern Brooklyn             Yorkshire Terrier                                85
# Southwest Brooklyn            Southwest Brooklyn            Shih Tzu                                         69
# Southwest Queens              Southwest Queens              Yorkshire Terrier                                53
# Stapleton and St. George      Stapleton and St. George      Shih Tzu                                         33
# Sunset Park                   Sunset Park                   Yorkshire Terrier                                32
# Upper East Side               Upper East Side               Havanese                                         94
# Upper West Side               Upper West Side               Labrador Retriever                              121
# West Central Queens           West Central Queens           Yorkshire Terrier                                72
# West Queens                   West Queens                   Shih Tzu                                         95

# %% [markdown]
# ## What breed of dogs are the least likely to be spayed? Male or female?

# %%
df.groupby(by="Animal Gender")["Spayed or Neut"].value_counts(normalize=True)
# Out:
# Animal Gender  Spayed or Neut
#                Yes               1.000000
# F              Yes               0.857565
#                No                0.142435
# M              Yes               0.791323
#                No                0.208677
# Name: Spayed or Neut, dtype: float64

# %% [markdown]
# ## Make a new column called monochrome that is True for any animal that only has black, white or grey as one of its colors. How many animals are monochrome?

# %%
df['monochrome'] = np.where((df["Animal Dominant Color"].str.upper() == "BLACK") | (df["Animal Dominant Color"].str.upper() == "WHITE") | (df["Animal Dominant Color"].str.upper() == "GREY") | (df["Animal Dominant Color"].str.upper() == "GRAY"), True, False)

df['monochrome'].value_counts()
# Out:
# True     15792
# False    13781
# Name: monochrome, dtype: int64

# %% [markdown]
# ## How many dogs are in each borough? Plot it in a graph.

# %%
df_number_borough = pd.DataFrame(df['borough'].value_counts(ascending=True))
df_number_borough
# Out:
#                borough
# Staten Island     2727
# Bronx             2748
# Queens            6154
# Brooklyn          7466
# Manhattan        10478

# %%
df_number_borough
# Out:
#                borough
# Staten Island     2727
# Bronx             2748
# Queens            6154
# Brooklyn          7466
# Manhattan        10478

# %%
df_number_borough.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Which borough has the highest number of dogs per-capita?
#
# You’ll need to merge in `population_boro.csv`

# %%
df_boro_pop = pd.read_csv("boro_population.csv")
df_boro_pop
# Out:
#          borough  population  area_sqmi
# 0      Manhattan     1644518         23
# 1          Bronx     1455444         42
# 2       Brooklyn     2636735         71
# 3         Queens     2339150        109
# 4  Staten Island      474558         59

# %%
df_number_borough.merge(df_boro_pop, left_index=True, right_on='borough')
df_number_borough
# Out:
#                borough
# Staten Island     2727
# Bronx             2748
# Queens            6154
# Brooklyn          7466
# Manhattan        10478

# %%
df_number_borough["dogs_per_cap"] = df_number_borough["borough_x"] / df_number_borough["population"]
df_number_borough.sort_values("dogs_per_cap", ascending=False).head(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'borough_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-0b561b14f8f4> in <module>
# ----> 1 df_number_borough["dogs_per_cap"] = df_number_borough["borough_x"] / df_number_borough["population"]
#       2 df_number_borough.sort_values("dogs_per_cap", ascending=False).head(1)
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'borough_x'

# %% [markdown]
# ## Make a bar graph of the top 5 breeds in each borough.
#
# How do you groupby and then only take the top X number? You **really** should ask me, because it's kind of crazy.

# %% [markdown]
# ## What percentage of dogs are not guard dogs?

# %%
df["Guard or Trained"].value_counts(normalize=True)
